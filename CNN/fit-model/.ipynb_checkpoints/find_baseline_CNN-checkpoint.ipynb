# %% [markdown]
# # find_best_models
#
# Fits various models to help intuit heuristic solutions to model architecture.
#
# ---

# %%
import keras 
from keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Loading in pre-processed data
# - Using binary classifications [i.e. use 0 (don't use) or 1 (use)] due to intrinsic mixing between messy and clean classifications.

# %%
# see ../pre-processing/clean_dataset/ for more info
filepath = '/Users/chrisduckworth/projects/ML_portfolio/kin_mis_classification/CNN/pre-processing/clean_dataset_files/'

X_train = np.load(filepath + 'X_train.npy')
X_test = np.load(filepath + 'X_test.npy')
X_val = np.load(filepath + 'X_val.npy')

y_train = np.load(filepath + 'y_train_binary.npy')
y_test = np.load(filepath + 'y_test_binary.npy')
y_val = np.load(filepath + 'y_val_binary.npy')

# %% [markdown]
# ### Double checking class imbalance and computing class weights as a result

# %%
sns.countplot(y_train)

# computing class weights from sklearn and converting to dict (needed for keras input)
weight = class_weight.compute_class_weight('balanced', 
                                           np.unique(y_train),
                                           y_train)

weight = {i : weight[i] for i in np.arange(weight.shape[0])}
weight
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass classes=[0 1], y=[0 1 0 ... 1 1 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# {0: 2.055411535968892, 1: 0.6607291666666667}

# %% [markdown]
# ### Using data generator objects to automatically augment training images to increase sample size.

# %%
train_gen = ImageDataGenerator(rotation_range = 45,  # randomly rotate images in the range (degrees, 0 to 180)
                               horizontal_flip = True, 
                               vertical_flip = True)  # randomly flip images

train_gen.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-6a64b53df951> in <module>
#       3                                vertical_flip = True)  # randomly flip images
#       4
# ----> 5 train_gen.fit(X_train)
#
# /opt/miniconda3/lib/python3.7/site-packages/keras_preprocessing/image/image_data_generator.py in fit(self, x, augment, rounds, seed)
#     934         if x.ndim != 4:
#     935             raise ValueError('Input to `.fit()` should have rank 4. '
# --> 936                              'Got array with shape: ' + str(x.shape))
#     937         if x.shape[self.channel_axis] not in {1, 3, 4}:
#     938             warnings.warn(
#
# ValueError: Input to `.fit()` should have rank 4. Got array with shape: (6343, 32, 32)

# %%
###

# %% [markdown]
# ### Reshaping X data (i.e. adding channel) for CNN input.

# %%
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]
X_val = X_val[..., np.newaxis]

# %%
model = build_seq_CNN((32, 32, 1))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               131200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 187,713
# Trainable params: 187,393
# Non-trainable params: 320
# _________________________________________________________________

# %%
model.fit(train_gen.flow(X_train, y_train, batch_size=32),
          validation_data=valid_gen.flow(X_val, y_val), 
          class_weight=weight, epochs=20)
# Out:
# Epoch 1/20
# 199/199 [==============================] - 5s 24ms/step - loss: 0.5084 - accuracy: 0.8045 - val_loss: 0.4854 - val_accuracy: 0.8080
# Epoch 2/20
# 199/199 [==============================] - 5s 24ms/step - loss: 0.3986 - accuracy: 0.8433 - val_loss: 0.6983 - val_accuracy: 0.7073
# Epoch 3/20
# 199/199 [==============================] - 5s 27ms/step - loss: 0.3845 - accuracy: 0.8449 - val_loss: 0.5618 - val_accuracy: 0.7475
# Epoch 4/20
# 199/199 [==============================] - 6s 29ms/step - loss: 0.3697 - accuracy: 0.8507 - val_loss: 0.6981 - val_accuracy: 0.6818
# Epoch 5/20
# 199/199 [==============================] - 6s 29ms/step - loss: 0.3615 - accuracy: 0.8573 - val_loss: 0.3972 - val_accuracy: 0.8369
# Epoch 6/20
# 199/199 [==============================] - 6s 29ms/step - loss: 0.3590 - accuracy: 0.8608 - val_loss: 0.4268 - val_accuracy: 0.8203
# Epoch 7/20
# 199/199 [==============================] - 6s 31ms/step - loss: 0.3347 - accuracy: 0.8668 - val_loss: 0.7319 - val_accuracy: 0.6761
# Epoch 8/20
# 199/199 [==============================] - 6s 32ms/step - loss: 0.3320 - accuracy: 0.8652 - val_loss: 0.4074 - val_accuracy: 0.8236
# Epoch 9/20
# 199/199 [==============================] - 7s 33ms/step - loss: 0.3348 - accuracy: 0.8646 - val_loss: 0.5252 - val_accuracy: 0.7749
# Epoch 10/20
# 199/199 [==============================] - 7s 33ms/step - loss: 0.3292 - accuracy: 0.8718 - val_loss: 0.4379 - val_accuracy: 0.7939
# Epoch 11/20
# 199/199 [==============================] - 7s 34ms/step - loss: 0.3177 - accuracy: 0.8750 - val_loss: 0.4038 - val_accuracy: 0.8303
# Epoch 12/20
# 199/199 [==============================] - 7s 35ms/step - loss: 0.3194 - accuracy: 0.8745 - val_loss: 0.4059 - val_accuracy: 0.8293
# Epoch 13/20
# 199/199 [==============================] - 7s 35ms/step - loss: 0.3165 - accuracy: 0.8772 - val_loss: 0.4551 - val_accuracy: 0.7943
# Epoch 14/20
# 199/199 [==============================] - 7s 34ms/step - loss: 0.3214 - accuracy: 0.8775 - val_loss: 0.4258 - val_accuracy: 0.8236
# Epoch 15/20
# 199/199 [==============================] - 7s 36ms/step - loss: 0.3173 - accuracy: 0.8751 - val_loss: 0.3346 - val_accuracy: 0.8586
# Epoch 16/20
# 199/199 [==============================] - 7s 35ms/step - loss: 0.3081 - accuracy: 0.8822 - val_loss: 0.3439 - val_accuracy: 0.8596
# Epoch 17/20
# 199/199 [==============================] - 7s 33ms/step - loss: 0.3085 - accuracy: 0.8792 - val_loss: 0.3874 - val_accuracy: 0.8416
# Epoch 18/20
# 199/199 [==============================] - 7s 33ms/step - loss: 0.3058 - accuracy: 0.8813 - val_loss: 0.4657 - val_accuracy: 0.7920
# Epoch 19/20
# 199/199 [==============================] - 7s 34ms/step - loss: 0.3059 - accuracy: 0.8846 - val_loss: 0.4227 - val_accuracy: 0.8199
# Epoch 20/20
# 199/199 [==============================] - 7s 35ms/step - loss: 0.3016 - accuracy: 0.8843 - val_loss: 0.3958 - val_accuracy: 0.8336

# %%
plot_loss_acc(model.history)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7feae8b288d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7feae8d268d0>],
#       dtype=object)

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3786 - accuracy: 0.8492

# %%
y_predict = model.predict(X_test)

# converting to definite classes.
y_predict_classes = (y_predict > 0.5).astype("int32")

plt.hist(y_test, label = 'Actual')
plt.hist(y_predict, alpha=0.6, label = 'Prediction value')
plt.hist(y_predict_classes, alpha=0.3, label = 'Prediction classes')
plt.legend()

# %%
plot_confusion_matrix(y_test, y_predict_classes, labels=['NO', 'ye'])

# %% [markdown]
# ### To do:
# - Unpack into functions.
# - Find optimal architecture using keras.tuner and number of layers.
# - Introduce different functional forms for learning rate (currently using adam which may already adapt).
# - Create learning rate plots and compare CNN vs FCN (for example).
# - Find package to visualise selected architecture.
